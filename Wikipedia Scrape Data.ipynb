# %% [markdown]
# <h1 style="font-family:Times New Roman"> <center>SCRAPING WIKIPEDIA DATA TO OBTAIN COUNTRY CODES </h1>

# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents
import numpy as np

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
#status code depicts that we can scrape
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

# %%
df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])

# %%
df
# Out:
#                                           ISO 3166[1]  \
#                                       Country name[5]
# 0                                         Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                       Åland Islands
# 3                                             Albania
# 4                                             Algeria
# ..                                                ...
# 275                                 Wallis and Futuna
# 276                               Western Sahara [ah]
# 277                                             Yemen
# 278                                            Zambia
# 279                                          Zimbabwe
#
#                                    Unnamed: 1_level_0  \
#                                Official state name[6]
# 0                 The Islamic Republic of Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                               Åland
# 3                             The Republic of Albania
# 4         The People's Democratic Republic of Algeria
# ..                                                ...
# 275    The Territory of the Wallis and Futuna Islands
# 276              The Sahrawi Arab Democratic Republic
# 277                             The Republic of Yemen
# 278                            The Republic of Zambia
# 279                          The Republic of Zimbabwe
#
#                                    Unnamed: 2_level_0  \
#                                  Sovereignty[6][7][8]
# 0                                     UN member state
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                             Finland
# 3                                     UN member state
# 4                                     UN member state
# ..                                                ...
# 275                                            France
# 276                                     Disputed [ai]
# 277                                   UN member state
# 278                                   UN member state
# 279                                   UN member state
#
#                                          ISO 3166-1[2]  \
#                                        Alpha-2 code[5]
# 0    .mw-parser-output .monospaced{font-family:mono...
# 1     Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                   AX
# 3                                                   AL
# 4                                                   DZ
# ..                                                 ...
# 275                                                 WF
# 276                                                 EH
# 277                                                 YE
# 278                                                 ZM
# 279                                                 ZW
#
#                                                        \
#                                       Alpha-3 code[5]
# 0                                                 AFG
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                 ALA
# 3                                                 ALB
# 4                                                 DZA
# ..                                                ...
# 275                                               WLF
# 276                                               ESH
# 277                                               YEM
# 278                                               ZMB
# 279                                               ZWE
#
#                                                        \
#                                       Numeric code[5]
# 0                                                 004
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                 248
# 3                                                 008
# 4                                                 012
# ..                                                ...
# 275                                               876
# 276                                               732
# 277                                               887
# 278                                               894
# 279                                               716
#
#                                         ISO 3166-2[3]  \
#                             Subdivision code links[3]
# 0                                       ISO 3166-2:AF
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                       ISO 3166-2:AX
# 3                                       ISO 3166-2:AL
# 4                                       ISO 3166-2:DZ
# ..                                                ...
# 275                                     ISO 3166-2:WF
# 276                                     ISO 3166-2:EH
# 277                                     ISO 3166-2:YE
# 278                                     ISO 3166-2:ZM
# 279                                     ISO 3166-2:ZW
#
#                                    Unnamed: 7_level_0
#                                     Internet ccTLD[9]
# 0                                                 .af
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                 .ax
# 3                                                 .al
# 4                                                 .dz
# ..                                                ...
# 275                                               .wf
# 276                                              [aj]
# 277                                               .ye
# 278                                               .zm
# 279                                               .zw
#
# [280 rows x 8 columns]

# %%
#let's preprocess the data set we need the country name and the alpha 2 code
df1=df.iloc[:,[0,3]]

# %%
df1
# Out:
#                                           ISO 3166[1]  \
#                                       Country name[5]
# 0                                         Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                       Åland Islands
# 3                                             Albania
# 4                                             Algeria
# ..                                                ...
# 275                                 Wallis and Futuna
# 276                               Western Sahara [ah]
# 277                                             Yemen
# 278                                            Zambia
# 279                                          Zimbabwe
#
#                                          ISO 3166-1[2]
#                                        Alpha-2 code[5]
# 0    .mw-parser-output .monospaced{font-family:mono...
# 1     Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                   AX
# 3                                                   AL
# 4                                                   DZ
# ..                                                 ...
# 275                                                 WF
# 276                                                 EH
# 277                                                 YE
# 278                                                 ZM
# 279                                                 ZW
#
# [280 rows x 2 columns]

# %%
df1.columns=['Country','Code']
df1
# Out:
#                                               Country  \
# 0                                         Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                       Åland Islands
# 3                                             Albania
# 4                                             Algeria
# ..                                                ...
# 275                                 Wallis and Futuna
# 276                               Western Sahara [ah]
# 277                                             Yemen
# 278                                            Zambia
# 279                                          Zimbabwe
#
#                                                   Code
# 0    .mw-parser-output .monospaced{font-family:mono...
# 1     Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                   AX
# 3                                                   AL
# 4                                                   DZ
# ..                                                 ...
# 275                                                 WF
# 276                                                 EH
# 277                                                 YE
# 278                                                 ZM
# 279                                                 ZW
#
# [280 rows x 2 columns]

# %%
df1['Code'].values
# Out:
# array(['.mw-parser-output .monospaced{font-family:monospace,monospace}AF',
#        'Akrotiri and Dhekelia – See United Kingdom, The.', 'AX', 'AL',
#        'DZ', 'AS', 'AD', 'AO', 'AI', 'AQ', 'AG', 'AR', 'AM', 'AW',
#        'Ashmore and Cartier Islands – See Australia.', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BM', 'BT', 'BO',
#        'BQ', 'BA', 'BW', 'BV', 'BR', 'IO',
#        'British Virgin Islands – See Virgin Islands (British).', 'BN',
#        'BG', 'BF', 'Burma – See Myanmar.', 'BI', 'CV', 'KH', 'CM', 'CA',
#        'Cape Verde – See Cabo Verde.',
#        'Caribbean Netherlands – See Bonaire, Sint Eustatius and Saba.',
#        'KY', 'CF', 'TD', 'CL', 'CN',
#        'China, The Republic of – See Taiwan (Province of China).', 'CX',
#        'Clipperton Island – See France.', 'CC', 'CO', 'KM', 'CD', 'CG',
#        'CK', 'Coral Sea Islands – See Australia.', 'CR', 'CI', 'HR', 'CU',
#        'CW', 'CY', 'CZ',
#        "Democratic People's Republic of Korea – See Korea, The Democratic People's Republic of.",
#        'Democratic Republic of the Congo – See Congo, The Democratic Republic of the.',
#        'DK', 'DJ', 'DM', 'DO', 'East Timor – See Timor-Leste.', 'EC',
#        'EG', 'SV', 'England – See United Kingdom, The.', 'GQ', 'ER', 'EE',
#        'SZ', 'ET', 'FK', 'FO', 'FJ', 'FI', 'FR', 'GF', 'PF', 'TF', 'GA',
#        'GM', 'GE', 'DE', 'GH', 'GI',
#        'Great Britain – See United Kingdom, The.', 'GR', 'GL', 'GD', 'GP',
#        'GU', 'GT', 'GG', 'GN', 'GW', 'GY', 'HT',
#        'Hawaiian Islands – See United States of America, The.', 'HM',
#        'VA', 'HN', 'HK', 'HU', 'IS', 'IN', 'ID', 'IR', 'IQ', 'IE', 'IM',
#        'IL', 'IT', "Ivory Coast – See Côte d'Ivoire.", 'JM',
#        'Jan Mayen – See Svalbard and Jan Mayen.', 'JP', 'JE', 'JO', 'KZ',
#        'KE', 'KI', 'KP', 'KR', 'KW', 'KG', 'LA', 'LV', 'LB', 'LS', 'LR',
#        'LY', 'LI', 'LT', 'LU', 'MO', 'MK', 'MG', 'MW', 'MY', 'MV', 'ML',
#        'MT', 'MH', 'MQ', 'MR', 'MU', 'YT', 'MX', 'FM', 'MD', 'MC', 'MN',
#        'ME', 'MS', 'MA', 'MZ', 'MM', nan, 'NR', 'NP', 'NL', 'NC', 'NZ',
#        'NI', 'NE', 'NG', 'NU', 'NF',
#        "North Korea – See Korea, The Democratic People's Republic of.",
#        'Northern Ireland – See United Kingdom, The.', 'MP', 'NO', 'OM',
#        'PK', 'PW', 'PS', 'PA', 'PG', 'PY',
#        "People's Republic of China – See China.", 'PE', 'PH', 'PN', 'PL',
#        'PT', 'PR', 'QA',
#        'Republic of China – See Taiwan (Province of China).',
#        'Republic of Korea – See Korea, The Republic of.',
#        'Republic of the Congo – See Congo, The.', 'RE', 'RO', 'RU', 'RW',
#        'Saba – See Bonaire, Sint Eustatius and Saba.',
#        'Sahrawi Arab Democratic Republic – See Western Sahara.', 'BL',
#        'SH', 'KN', 'LC', 'MF', 'PM', 'VC', 'WS', 'SM', 'ST', 'SA',
#        'Scotland – See United Kingdom, The.', 'SN', 'RS', 'SC', 'SL',
#        'SG', 'Sint Eustatius – See Bonaire, Sint Eustatius and Saba.',
#        'SX', 'SK', 'SI', 'SB', 'SO', 'ZA', 'GS',
#        'South Korea – See Korea, The Republic of.', 'SS', 'ES', 'LK',
#        'SD', 'SR', 'SJ', 'SE', 'CH', 'SY', 'TW', 'TJ', 'TZ', 'TH', 'TL',
#        'TG', 'TK', 'TO', 'TT', 'TN', 'TR', 'TM', 'TC', 'TV', 'UG', 'UA',
#        'AE', 'GB', 'UM', 'US',
#        'United States Virgin Islands – See Virgin Islands (U.S.).', 'UY',
#        'UZ', 'VU', 'Vatican City – See Holy See, The.', 'VE', 'VN', 'VG',
#        'VI', 'Wales – See United Kingdom, The.', 'WF', 'EH', 'YE', 'ZM',
#        'ZW'], dtype=object)

# %%
#let's mark the positions of those country codes that have a length equal to 2
pos=[]
non=[]
for x in range(len(df1)):
    if len(str(df1.Code[x]))==2:
        pos.append(x)
    else:
        non.append(x)

# %%
df_clnd=df1.iloc[pos,:].reset_index(drop=True)

# %%
df_clnd
# Out:
#                  Country Code
# 0          Åland Islands   AX
# 1                Albania   AL
# 2                Algeria   DZ
# 3         American Samoa   AS
# 4                Andorra   AD
# ..                   ...  ...
# 242    Wallis and Futuna   WF
# 243  Western Sahara [ah]   EH
# 244                Yemen   YE
# 245               Zambia   ZM
# 246             Zimbabwe   ZW
#
# [247 rows x 2 columns]

# %%
df_rvwd=df1.iloc[non,:].reset_index(drop=True)

# %%
df_rvwd['Code'][:1]=df_rvwd.iloc[0]['Code'][-2:]

# %%
cc_df=df_clnd.append(df_rvwd[:1]).sort_values(by="Country",ascending=True)

# %%
cc_df.reset_index(drop=True,inplace=True)

# %%
cc_df
# Out:
#                  Country Code
# 0            Afghanistan   AF
# 1                Albania   AL
# 2                Algeria   DZ
# 3         American Samoa   AS
# 4                Andorra   AD
# ..                   ...  ...
# 243  Western Sahara [ah]   EH
# 244                Yemen   YE
# 245               Zambia   ZM
# 246             Zimbabwe   ZW
# 247        Åland Islands   AX
#
# [248 rows x 2 columns]

# %%
cc_df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica\u200a[a]', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia\u200a[b]', 'Austria',
#        'Azerbaijan', 'Bahamas (the)', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire\xa0Sint Eustatius\xa0Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Bouvet Island', 'Brazil',
#        'British Indian Ocean Territory (the)',
#        'Brunei Darussalam\u200a[e]', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cabo Verde\u200a[f]', 'Cambodia', 'Cameroon', 'Canada',
#        'Cayman Islands (the)', 'Central African Republic (the)', 'Chad',
#        'Chile', 'China', 'Christmas Island',
#        'Cocos (Keeling) Islands (the)', 'Colombia', 'Comoros (the)',
#        'Congo (the Democratic Republic of the)', 'Congo (the)\u200a[g]',
#        'Cook Islands (the)', 'Costa Rica', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia\u200a[i]', "Côte d'Ivoire\u200a[h]", 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic (the)', 'Ecuador',
#        'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini\u200a[j]', 'Ethiopia',
#        'Falkland Islands (the) [Malvinas]\u200a[k]',
#        'Faroe Islands (the)', 'Fiji', 'Finland', 'France\u200a[l]',
#        'French Guiana', 'French Polynesia',
#        'French Southern Territories (the)\u200a[m]', 'Gabon',
#        'Gambia (the)', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'Heard Island and McDonald Islands',
#        'Holy See (the)\u200a[n]', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran (Islamic Republic of)',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea (the Democratic People's Republic of)\u200a[o]",
#        'Korea (the Republic of)\u200a[p]', 'Kuwait', 'Kyrgyzstan',
#        "Lao People's Democratic Republic (the)\u200a[q]", 'Latvia',
#        'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Macao\u200a[r]', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands (the)', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (Federated States of)',
#        'Moldova (the Republic of)', 'Monaco', 'Mongolia', 'Montenegro',
#        'Montserrat', 'Morocco', 'Mozambique', 'Myanmar\u200a[t]', 'Nauru',
#        'Nepal', 'Netherlands (the)', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger (the)', 'Nigeria', 'Niue', 'Norfolk Island',
#        'North Macedonia\u200a[s]', 'Northern Mariana Islands (the)',
#        'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestine, State of',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines (the)', 'Pitcairn\u200a[u]', 'Poland', 'Portugal',
#        'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation (the)\u200a[v]', 'Rwanda', 'Réunion',
#        'Saint Barthélemy',
#        'Saint Helena\xa0Ascension Island\xa0Tristan da Cunha',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa',
#        'South Georgia and the South Sandwich Islands', 'South Sudan',
#        'Spain', 'Sri Lanka', 'Sudan (the)', 'Suriname',
#        'Svalbard\xa0Jan Mayen', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic (the)\u200a[x]',
#        'Taiwan (Province of China)\u200a[y]', 'Tajikistan',
#        'Tanzania, the United Republic of', 'Thailand',
#        'Timor-Leste\u200a[aa]', 'Togo', 'Tokelau', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkmenistan',
#        'Turks and Caicos Islands (the)', 'Tuvalu', 'Türkiye', 'Uganda',
#        'Ukraine', 'United Arab Emirates (the)',
#        'United Kingdom of Great Britain and Northern Ireland (the)',
#        'United States Minor Outlying Islands (the)\u200a[ac]',
#        'United States of America (the)', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam\u200a[ae]', 'Virgin Islands (British)\u200a[af]',
#        'Virgin Islands (U.S.)\u200a[ag]', 'Wallis and Futuna',
#        'Western Sahara\u200a[ah]', 'Yemen', 'Zambia', 'Zimbabwe',
#        'Åland Islands'], dtype=object)

# %%
df=pd.read_csv("ds_salaries.csv")

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
list1=list(set(cc_df['Code'].unique()).intersection(set(df.company_location.unique())))

# %%
cc_df1=cc_df[cc_df.Code.isin(list1)]

# %%
cc_df1
# Out:
#                                                Country Code
# 2                                              Algeria   DZ
# 3                                       American Samoa   AS
# 12                                       Australia [b]   AU
# 13                                             Austria   AT
# 20                                             Belgium   BE
# 30                                              Brazil   BR
# 39                                              Canada   CA
# 43                                               Chile   CL
# 44                                               China   CN
# 47                                            Colombia   CO
# 53                                             Croatia   HR
# 57                                         Czechia [i]   CZ
# 59                                             Denmark   DK
# 68                                             Estonia   EE
# 75                                          France [l]   FR
# 82                                             Germany   DE
# 85                                              Greece   GR
# 98                                            Honduras   HN
# 100                                            Hungary   HU
# 102                                              India   IN
# 104                         Iran (Islamic Republic of)   IR
# 105                                               Iraq   IQ
# 106                                            Ireland   IE
# 108                                             Israel   IL
# 109                                              Italy   IT
# 111                                              Japan   JP
# 115                                              Kenya   KE
# 129                                         Luxembourg   LU
# 133                                           Malaysia   MY
# 136                                              Malta   MT
# 142                                             Mexico   MX
# 144                          Moldova (the Republic of)   MD
# 154                                  Netherlands (the)   NL
# 156                                        New Zealand   NZ
# 159                                            Nigeria   NG
# 166                                           Pakistan   PK
# 175                                             Poland   PL
# 176                                           Portugal   PT
# 179                                            Romania   RO
# 180                       Russian Federation (the) [v]   RU
# 198                                          Singapore   SG
# 201                                           Slovenia   SI
# 207                                              Spain   ES
# 213                                        Switzerland   CH
# 228                                            Türkiye   TR
# 230                                            Ukraine   UA
# 231                         United Arab Emirates (the)   AE
# 232  United Kingdom of Great Britain and Northern I...   GB
# 234                     United States of America (the)   US
# 239                                      Viet Nam [ae]   VN

# %%
cc_df1.duplicated().any()
# Out:
# False

# %%
cc_df1['Country']=np.where(cc_df1['Country']=="Viet Nam [ae]","Vietnam",cc_df1['Country'])
# Out:
# <ipython-input-31-ee94db2d9930>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="Viet Nam [ae]","Vietnam",cc_df1['Country'])

# %%
cc_df1
# Out:
#                                                Country Code
# 2                                              Algeria   DZ
# 3                                       American Samoa   AS
# 12                                       Australia [b]   AU
# 13                                             Austria   AT
# 20                                             Belgium   BE
# 30                                              Brazil   BR
# 39                                              Canada   CA
# 43                                               Chile   CL
# 44                                               China   CN
# 47                                            Colombia   CO
# 53                                             Croatia   HR
# 57                                         Czechia [i]   CZ
# 59                                             Denmark   DK
# 68                                             Estonia   EE
# 75                                          France [l]   FR
# 82                                             Germany   DE
# 85                                              Greece   GR
# 98                                            Honduras   HN
# 100                                            Hungary   HU
# 102                                              India   IN
# 104                         Iran (Islamic Republic of)   IR
# 105                                               Iraq   IQ
# 106                                            Ireland   IE
# 108                                             Israel   IL
# 109                                              Italy   IT
# 111                                              Japan   JP
# 115                                              Kenya   KE
# 129                                         Luxembourg   LU
# 133                                           Malaysia   MY
# 136                                              Malta   MT
# 142                                             Mexico   MX
# 144                          Moldova (the Republic of)   MD
# 154                                  Netherlands (the)   NL
# 156                                        New Zealand   NZ
# 159                                            Nigeria   NG
# 166                                           Pakistan   PK
# 175                                             Poland   PL
# 176                                           Portugal   PT
# 179                                            Romania   RO
# 180                       Russian Federation (the) [v]   RU
# 198                                          Singapore   SG
# 201                                           Slovenia   SI
# 207                                              Spain   ES
# 213                                        Switzerland   CH
# 228                                            Türkiye   TR
# 230                                            Ukraine   UA
# 231                         United Arab Emirates (the)   AE
# 232  United Kingdom of Great Britain and Northern I...   GB
# 234                     United States of America (the)   US
# 239                                            Vietnam   VN

# %%
cc_df1['Country']=np.where(cc_df1['Country']=="Czechia [i]","Czech Republic",cc_df1['Country'])
cc_df1['Country']=np.where(cc_df1['Country']=="Australia [b]","Australia",cc_df1['Country'])
cc_df1['Country']=np.where(cc_df1['Country']=="France [l]","France",cc_df1['Country'])
cc_df1['Country']=np.where(cc_df1['Country']=="Russia Russian Federation (the) [v]","Russia",cc_df1['Country'])
cc_df1['Country']=np.where(cc_df1['Country']=="United States of America (the)","The United States of America",cc_df1['Country'])
cc_df1['Country']=np.where(cc_df1['Country']=="United Arab Emirates (the)","The United Arab Emirates",cc_df1['Country'])
cc_df1
# Out:
# <ipython-input-33-c47398821e25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="Czechia [i]","Czech Republic",cc_df1['Country'])
# <ipython-input-33-c47398821e25>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="Australia [b]","Australia",cc_df1['Country'])
# <ipython-input-33-c47398821e25>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="France [l]","France",cc_df1['Country'])
# <ipython-input-33-c47398821e25>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="Russia Russian Federation (the) [v]","Russia",cc_df1['Country'])
# <ipython-input-33-c47398821e25>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="United States of America (the)","The United States of America",cc_df1['Country'])
# <ipython-input-33-c47398821e25>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="United Arab Emirates (the)","The United Arab Emirates",cc_df1['Country'])
#                                                Country Code
# 2                                              Algeria   DZ
# 3                                       American Samoa   AS
# 12                                           Australia   AU
# 13                                             Austria   AT
# 20                                             Belgium   BE
# 30                                              Brazil   BR
# 39                                              Canada   CA
# 43                                               Chile   CL
# 44                                               China   CN
# 47                                            Colombia   CO
# 53                                             Croatia   HR
# 57                                      Czech Republic   CZ
# 59                                             Denmark   DK
# 68                                             Estonia   EE
# 75                                              France   FR
# 82                                             Germany   DE
# 85                                              Greece   GR
# 98                                            Honduras   HN
# 100                                            Hungary   HU
# 102                                              India   IN
# 104                         Iran (Islamic Republic of)   IR
# 105                                               Iraq   IQ
# 106                                            Ireland   IE
# 108                                             Israel   IL
# 109                                              Italy   IT
# 111                                              Japan   JP
# 115                                              Kenya   KE
# 129                                         Luxembourg   LU
# 133                                           Malaysia   MY
# 136                                              Malta   MT
# 142                                             Mexico   MX
# 144                          Moldova (the Republic of)   MD
# 154                                  Netherlands (the)   NL
# 156                                        New Zealand   NZ
# 159                                            Nigeria   NG
# 166                                           Pakistan   PK
# 175                                             Poland   PL
# 176                                           Portugal   PT
# 179                                            Romania   RO
# 180                       Russian Federation (the) [v]   RU
# 198                                          Singapore   SG
# 201                                           Slovenia   SI
# 207                                              Spain   ES
# 213                                        Switzerland   CH
# 228                                            Türkiye   TR
# 230                                            Ukraine   UA
# 231                           The United Arab Emirates   AE
# 232  United Kingdom of Great Britain and Northern I...   GB
# 234                       The United States of America   US
# 239                                            Vietnam   VN

# %%
cc_df1['Country']=np.where(cc_df1['Country']=="Türkiye","Turkey",cc_df1['Country'])
# Out:
# <ipython-input-35-7673eb0002fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cc_df1['Country']=np.where(cc_df1['Country']=="Türkiye","Turkey",cc_df1['Country'])

# %%
cc_df1.reset_index(inplace=True,drop=True)
cc_df1.head()
# Out:
#           Country Code
# 0         Algeria   DZ
# 1  American Samoa   AS
# 2       Australia   AU
# 3         Austria   AT
# 4         Belgium   BE

# %%
df_final=pd.merge(df,cc_df1,how='inner',left_on="company_location",right_on='Code')

# %%
df_final['company_location']=df_final['Country']
df_final.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2020               MI              FT            Data Scientist
# 1       2020               MI              FT  Data Engineering Manager
# 2       2020               EN              PT               ML Engineer
# 3       2020               EN              FT             Data Engineer
# 4       2020               SE              FT  Principal Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1   51999             EUR          59303                 DE           100
# 2   14000             EUR          15966                 DE           100
# 3   48000             EUR          54742                 PK           100
# 4  130000             EUR         148261                 DE           100
#
#   company_location company_size  Country Code
# 0          Germany            L  Germany   DE
# 1          Germany            S  Germany   DE
# 2          Germany            S  Germany   DE
# 3          Germany            L  Germany   DE
# 4          Germany            M  Germany   DE

# %%
df_final.drop(columns=['Country','Code'],inplace=True)

# %%
df_final
# Out:
#      work_year experience_level employment_type  \
# 0         2020               MI              FT
# 1         2020               MI              FT
# 2         2020               EN              PT
# 3         2020               EN              FT
# 4         2020               SE              FT
# ..         ...              ...             ...
# 602       2022               EN              FT
# 603       2022               MI              FT
# 604       2022               EN              FT
# 605       2022               EN              FT
# 606       2022               SE              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 0                       Data Scientist   70000             EUR          79833
# 1             Data Engineering Manager   51999             EUR          59303
# 2                          ML Engineer   14000             EUR          15966
# 3                        Data Engineer   48000             EUR          54742
# 4             Principal Data Scientist  130000             EUR         148261
# ..                                 ...     ...             ...            ...
# 602                     Data Scientist   40000             USD          40000
# 603          Machine Learning Engineer  121000             AUD          87425
# 604                     Data Scientist  120000             AUD          86703
# 605  Computer Vision Software Engineer  150000             USD         150000
# 606          Machine Learning Engineer   65000             EUR          71444
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0          Germany            L
# 1                   DE           100          Germany            S
# 2                   DE           100          Germany            S
# 3                   PK           100          Germany            L
# 4                   DE           100          Germany            M
# ..                 ...           ...              ...          ...
# 602                 JP           100         Malaysia            L
# 603                 AU           100        Australia            L
# 604                 AU            50        Australia            M
# 605                 AU           100        Australia            S
# 606                 IE           100          Ireland            S
#
# [607 rows x 11 columns]

# %%
df_final=pd.merge(df_final,cc_df1,how='inner',left_on="employee_residence",right_on='Code')

# %%
df_final['employee_residence']=df_final['Country']
df_final.drop(columns=['Country','Code'],inplace=True)

# %%
df_final
# Out:
#      work_year experience_level employment_type  \
# 0         2020               MI              FT
# 1         2020               MI              FT
# 2         2020               EN              PT
# 3         2020               SE              FT
# 4         2020               EN              FT
# ..         ...              ...             ...
# 593       2022               MI              FT
# 594       2022               MI              FT
# 595       2022               EN              FT
# 596       2022               EN              FT
# 597       2022               SE              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 0                       Data Scientist   70000             EUR          79833
# 1             Data Engineering Manager   51999             EUR          59303
# 2                          ML Engineer   14000             EUR          15966
# 3             Principal Data Scientist  130000             EUR         148261
# 4                       Data Scientist   55000             EUR          62726
# ..                                 ...     ...             ...            ...
# 593                       Head of Data   30000             EUR          32974
# 594          Machine Learning Engineer  121000             AUD          87425
# 595                     Data Scientist  120000             AUD          86703
# 596  Computer Vision Software Engineer  150000             USD         150000
# 597          Machine Learning Engineer   65000             EUR          71444
#
#     employee_residence  remote_ratio company_location company_size
# 0              Germany             0          Germany            L
# 1              Germany           100          Germany            S
# 2              Germany           100          Germany            S
# 3              Germany           100          Germany            M
# 4              Germany            50          Germany            S
# ..                 ...           ...              ...          ...
# 593            Estonia           100          Estonia            S
# 594          Australia           100        Australia            L
# 595          Australia            50        Australia            M
# 596          Australia           100        Australia            S
# 597            Ireland           100          Ireland            S
#
# [598 rows x 11 columns]

# %%
#a feature that identifies if the employee stays in the same country or not
def local(row):
    residence=row[0]
    office=row[1]
    if office==residence:
        return 1
    else:
        return 0

# %%
df_final['local']=df_final[['employee_residence','company_location']].apply(local,axis='columns')

# %%
df_final['local'].value_counts()
# Out:
# 1    556
# 0     42
# Name: local, dtype: int64

# %%
#a feature to distinguish jobs in India and abroad
df_final['abroad']=np.where(df_final['salary_currency']=='INR',0,1)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 597
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           598 non-null    int64
#  1   experience_level    598 non-null    object
#  2   employment_type     598 non-null    object
#  3   job_title           598 non-null    object
#  4   salary              598 non-null    int64
#  5   salary_currency     598 non-null    object
#  6   salary_in_usd       598 non-null    int64
#  7   employee_residence  598 non-null    object
#  8   remote_ratio        598 non-null    int64
#  9   company_location    598 non-null    object
#  10  company_size        598 non-null    object
#  11  local               598 non-null    int64
#  12  abroad              598 non-null    int32
# dtypes: int32(1), int64(5), object(7)
# memory usage: 63.1+ KB

# %%
df_final.to_csv('ds_sal_scraped_cleaned_data.csv')

# %%
cc_df1.to_csv('wikipedia_cc_data.csv')
